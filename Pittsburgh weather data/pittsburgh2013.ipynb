# %%
import pandas as pd

weather = pd.read_csv('pittsburgh2013.csv', index_col='Date', parse_dates=True)
weather.head()
# Out:
#             Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# Date
# 2013-01-01                32                 28                21
# 2013-01-02                25                 21                17
# 2013-01-03                32                 24                16
# 2013-01-04                30                 28                27
# 2013-01-05                34                 30                25
#
#             Max Dew PointF  Mean Dew PointF  Min DewpointF  Max Humidity  \
# Date
# 2013-01-01              30               27             16           100
# 2013-01-02              14               12             10            77
# 2013-01-03              19               15              9            77
# 2013-01-04              21               19             17            75
# 2013-01-05              23               20             16            75
#
#             Mean Humidity  Min Humidity  Max Sea Level PressureIn  \
# Date
# ...

# %%
weather.loc['2013-7-1':'2013-7-7', 'PrecipitationIn']
# Out:
# Date
# 2013-07-01    0.18
# 2013-07-02    0.14
# 2013-07-03    0.00
# 2013-07-04    0.25
# 2013-07-05    0.02
# 2013-07-06    0.06
# 2013-07-07    0.10
# Freq: D, Name: PrecipitationIn, dtype: float64

# %%
# convert inches to centimeteres

weather.loc['2013-07-01':'2013-07-07', 'PrecipitationIn'] * 2.54
# Out:
# Date
# 2013-07-01    0.4572
# 2013-07-02    0.3556
# 2013-07-03    0.0000
# 2013-07-04    0.6350
# 2013-07-05    0.0508
# 2013-07-06    0.1524
# 2013-07-07    0.2540
# Freq: D, Name: PrecipitationIn, dtype: float64

# %%
week1_range = weather.loc['2013-07-01':'2013-07-07', ['Min TemperatureF', 'Max TemperatureF']]
print(week1_range)
# Out:
#             Min TemperatureF  Max TemperatureF
# Date
# 2013-07-01                66                79
# 2013-07-02                66                84
# 2013-07-03                71                86
# 2013-07-04                70                86
# 2013-07-05                69                86
# 2013-07-06                70                89
# 2013-07-07                70                77

# %%
week1_mean = weather.loc['2013-07-01':'2013-07-07','Mean TemperatureF']
print(week1_mean)
# Out:
# Date
# 2013-07-01    72
# 2013-07-02    74
# 2013-07-03    78
# 2013-07-04    77
# 2013-07-05    76
# 2013-07-06    78
# 2013-07-07    72
# Freq: D, Name: Mean TemperatureF, dtype: int64

# %%
## Relative temprature range 
week1_range.divide(week1_mean, axis='rows')
# Out:
#             Min TemperatureF  Max TemperatureF
# Date
# 2013-07-01          0.916667          1.097222
# 2013-07-02          0.891892          1.135135
# 2013-07-03          0.910256          1.102564
# 2013-07-04          0.909091          1.116883
# 2013-07-05          0.907895          1.131579
# 2013-07-06          0.897436          1.141026
# 2013-07-07          0.972222          1.069444

# %%
# Percentage changes

# subtracting the previuose day's value from the current day's value and dividing by the previouse day value.
week1_mean.pct_change() * 100
# Out:
# Date
# 2013-07-01         NaN
# 2013-07-02    2.777778
# 2013-07-03    5.405405
# 2013-07-04   -1.282051
# 2013-07-05   -1.298701
# 2013-07-06    2.631579
# 2013-07-07   -7.692308
# Freq: D, Name: Mean TemperatureF, dtype: float64

# %% [markdown]
# #### Convert degrees Fahrenheit to degrees Celsius

# %%
# Write a function to convert degrees Fahrenheit to degrees Celsius: to_celsius
def to_celsius(F):
    return 5/9*(F - 32)

# Apply the function over 'Mean TemperatureF' and 'Mean Dew PointF': df_celsius
df_celsius = weather[['Mean TemperatureF','Mean Dew PointF']].apply(to_celsius)

# Reassign the columns df_celsius
df_celsius.columns = ['Mean TemperatureC', 'Mean Dew PointC']

# Print the output of df_celsius.head()
df_celsius.head()
# Out:
#             Mean TemperatureC  Mean Dew PointC
# Date
# 2013-01-01          -2.222222        -2.777778
# 2013-01-02          -6.111111       -11.111111
# 2013-01-03          -4.444444        -9.444444
# 2013-01-04          -2.222222        -7.222222
# 2013-01-05          -1.111111        -6.666667

# %%
# Extract selected columns from weather as new DataFrame: temps_f
temps_f = weather[['Min TemperatureF', 'Mean TemperatureF','Max TemperatureF']]

# Convert temps_f to celsius: temps_c
temps_c = (temps_f - 32) * 5/9

# Rename 'F' in column names with 'C': temps_c.columns
temps_c.columns = temps_c.columns.str.replace('F', 'C')

# Print first 5 rows of temps_c
print(temps_c.head())
# Out:
#             Min TemperatureC  Mean TemperatureC  Max TemperatureC
# Date
# 2013-01-01         -6.111111          -2.222222          0.000000
# 2013-01-02         -8.333333          -6.111111         -3.888889
# 2013-01-03         -8.888889          -4.444444          0.000000
# 2013-01-04         -2.777778          -2.222222         -1.111111
# 2013-01-05         -3.888889          -1.111111          1.111111

# %%
# Print the mean of the January and March data
january = weather.loc['2013-01','Mean TemperatureF']
march = weather.loc['2013-03','Mean TemperatureF']


print(january.mean(), march.mean())

# Print the standard deviation of the January and March data
print(january.std(), march.std())
# Out:
# 32.354838709677416 35.0
# 13.583196450263523 7.478859093025709
